# %%
import pandas as pd 
import matplotlib as plt 
import os

data_path = os.path.join('exoTest.csv', 'exoTest.csv')
planet_data = pd.read_csv(data_path)

# %%
print(f'The data contains {planet_data.shape[0]} rows and {planet_data.shape[1]} columns')
print('\nHere is the overview of the data')
planet_data.head()
# Out:
# The data contains 570 rows and 3198 columns
#
# Here is the overview of the data
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0      2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1      2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2      2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3      2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4      2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
#
#     FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0     6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1  5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2   362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3  -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4   -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
#
# ...

# %%
print('Info about what type of values data contains\n')
planet_data.info()
# Out:
# Info about what type of values data contains
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Columns: 3198 entries, LABEL to FLUX.3197
# dtypes: float64(3197), int64(1)
# memory usage: 13.9 MB

# %%
print('Here is the statistics of the dataset\n')
planet_data.describe()
# Out:
# Here is the statistics of the dataset
#             LABEL         FLUX.1         FLUX.2         FLUX.3         FLUX.4  \
# count  570.000000     570.000000     570.000000     570.000000     570.000000
# mean     1.008772     515.411351     738.046404     532.603246     739.618088
# std      0.093329   12592.950138   12622.940170   12545.065255   12591.933126
# min      1.000000  -59421.000000  -14663.430000  -56580.000000  -10817.590000
# 25%      1.000000     -22.230000     -22.912500     -22.985000     -18.662500
# 50%      1.000000       1.195000       0.410000      -1.125000      -0.880000
# 75%      1.000000      98.317500      89.710000      89.827500      73.257500
# max      2.000000  290882.500000  290653.500000  290554.000000  290486.500000
#
#               FLUX.5         FLUX.6         FLUX.7         FLUX.8  \
# count     570.000000     570.000000     570.000000     570.000000
# mean      530.949807     729.591491     517.421404     720.723544
# ...

# %%
planet_data.T
# Out:
#               0        1       2       3      4      5       6      7    \
# LABEL        2.00     2.00    2.00    2.00   2.00   1.00    1.00   1.00
# FLUX.1     119.88  5736.59  844.48 -826.00 -39.57  14.28 -150.48 -10.06
# FLUX.2     100.21  5699.98  817.49 -827.31 -15.88  10.63 -141.72 -12.78
# FLUX.3      86.46  5717.16  770.07 -846.12  -9.16  14.56 -157.60 -13.16
# FLUX.4      48.68  5692.73  675.01 -836.03  -6.37  12.42 -184.60  -9.81
# ...           ...      ...     ...     ...    ...    ...     ...    ...
# FLUX.3193   45.50 -2061.17 -174.54   20.75 -85.34  -4.78   -8.40  35.89
# FLUX.3194   31.93 -2265.98  -95.23   20.25 -81.46  -4.34  -16.80 -33.44
# FLUX.3195   35.78 -2366.19 -162.68 -120.81 -61.98   7.67   -8.03 -30.83
# FLUX.3196  269.43 -2294.86  -36.79 -257.56 -69.34  -0.33  -12.73 -33.00
# FLUX.3197   57.72 -2034.72   30.63 -215.41 -17.84  -7.53  -11.41 -20.15
#
#               8       9    ...    560    561    562    563     564     565  \
# ...

# %%
planet_data.iloc[0].plot()
# Out:
# <Axes: >

# %%
# %pip install statsmodels
# Out:
# ...
#   Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
# Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl (9.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\jiwan\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\statsmodels\\base\\_prediction_inference.py'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
#   Cell In[36], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax
